# %%
pip install tensorflow
# Out:
# ...
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/0f/a5/89a9bdae9f241cad167edb6c890ef2b4c842c5ae81058a2fbfd702dba9bf/tensorflow-2.17.0-cp311-cp311-macosx_12_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/a2/ad/e0d3c824784ff121c03cc031f944bc7e139a8f1870ffd2845cc2dd76f6c4/absl_py-2.1.0-py3-none-any.whl.metadata
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Obtaining dependency information for astunparse>=1.6.0 from https://files.pythonhosted.org/packages/2b/03/13dde6512ad7b4557eb792fbcf0c653af6076b81e5941d36ec61f7ce6028/astunparse-1.6.3-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for flatbuffers>=24.3.25 from https://files.pythonhosted.org/packages/41/f0/7e988a019bc54b2dbd0ad4182ef2d53488bb02e58694cd79d61369e85900/flatbuffers-24.3.25-py2.py3-none-any.whl.metadata
# ...

# %%
from deeppavlov import build_model

model = build_model("ner_rus_bert.json", install=True, download=True)

# get predictions for 'input_text1', 'input_text2'


texts = ["перевод на Роман Александрович", "transfer to Roman"]
model([texts])
# Out:
# ERROR: Could not find a version that satisfies the requirement torch<1.14.0,>=1.6.0 (from versions: 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1)
# ERROR: No matching distribution found for torch<1.14.0,>=1.6.0
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[6], line 3
#       1 from deeppavlov import build_model
# ----> 3 model = build_model("ner_rus_bert.json", install=True, download=True)
#       5 # get predictions for 'input_text1', 'input_text2'
#       8 texts = ["перевод на Роман Александрович", "transfer to Roman"]
#
# File ~/Desktop/code/consultant_ai/ner_for_names/env/lib/python3.11/site-packages/deeppavlov/core/commands/infer.py:37, in build_model(config, mode, load_trained, install, download)
# ...

# %%
# !pip install transformers
# Out:
# ...
#   Obtaining dependency information for transformers from https://files.pythonhosted.org/packages/75/35/07c9879163b603f0e464b0f6e6e628a2340cfc7cdc5ca8e7d52d776710d4/transformers-4.44.2-py3-none-any.whl.metadata
#   Using cached transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# ...
#   Obtaining dependency information for huggingface-hub<1.0,>=0.23.2 from https://files.pythonhosted.org/packages/57/28/a0b0dd3cca63908045edc300360d6cd8758d4d86eee3fd2b08f00c5a41c4/huggingface_hub-0.24.7-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pyyaml>=5.1 from https://files.pythonhosted.org/packages/8b/62/b9faa998fd185f65c1371643678e4d58254add437edb764a08c5a98fb986/PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# ...

# %%
# !pip install tf-keras
# Out:
# ...
#   Obtaining dependency information for tf-keras from https://files.pythonhosted.org/packages/21/8b/75f7572ec0273ed8da50bc19defe08aaaafcc15fda3407db53f49acec814/tf_keras-2.17.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 2.8 MB/s eta 0:00:00m eta 0:00:010:01:010m
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline(task="ner", model="elmurod1202/bertbek-news-big-cased")
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at elmurod1202/bertbek-news-big-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/aslonkhamidov/Desktop/code/consultant_ai/ner_for_names/env/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
def print_results(results):
    for result in results:
        print(f"entity: {result['entity']}, {result['word']}, score: {result['score']}, index: {result['index']}")

# %%
texts = [
    "Barsaning payshanba kungi Monakoga qarshi o'yinini Allard Lindhout boshqarib boradi. 37 yoshli niderlandiyalik hakam ilgari 'Barselona'ning o'yinlarini boshqarmagan, ammo o'tgan mart oyida Montjuikda 'Napoli'ga qarshi o'yin (3-1 hisobida Barselonaning g'alabasi bilan yakunlangan) davomida to'rtinchi hakam sifatida ishlagan.",
]

# %%
results = pipe(texts[0])
print_results(results)
# Out:
# entity: LABEL_1, Barsa, score: 0.598750650882721, index: 1
# entity: LABEL_0, ##ning, score: 0.5400611162185669, index: 2
# entity: LABEL_0, payshanba, score: 0.5165401697158813, index: 3
# entity: LABEL_0, kungi, score: 0.5884608030319214, index: 4
# entity: LABEL_0, Monako, score: 0.5205005407333374, index: 5
# entity: LABEL_0, ##ga, score: 0.7834370732307434, index: 6
# entity: LABEL_0, qarshi, score: 0.5779159069061279, index: 7
# entity: LABEL_0, o, score: 0.6254765391349792, index: 8
# entity: LABEL_1, ', score: 0.5055612325668335, index: 9
# entity: LABEL_1, yinini, score: 0.5777100324630737, index: 10
# entity: LABEL_0, Alla, score: 0.5390616059303284, index: 11
# entity: LABEL_0, ##rd, score: 0.6540327072143555, index: 12
# entity: LABEL_0, Lind, score: 0.6306067705154419, index: 13
# entity: LABEL_0, ##ho, score: 0.577721357345581, index: 14
# entity: LABEL_1, ##ut, score: 0.5216262340545654, index: 15
# entity: LABEL_0, boshqarib, score: 0.5160596370697021, index: 16
# ...

# %%
import json
with open("data/problematic_1216.txt", "r") as file:
    text = file.read()
    json.loads(text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[32], line 4
#       2 with open("data/problematic_1216.txt", "r") as file:
#       3     text = file.read()
# ----> 4     json.loads(text)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:340, in JSONDecoder.decode(self, s, _w)
# ...
